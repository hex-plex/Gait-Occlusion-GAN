# %%
import numpy as np
from scipy import stats

# %%
def manhattan_dst(row1, row2):
    return sum([abs(r1-r2) for r1,r2 in zip(row1,row2)])

def get_neigh(train,test_row,num_neigh):
    return sorted(train, key = lambda train_r : manhattan_dst(train_r,test_row))[:num_neigh]

# %%
def predict_classification(train, test_row, num_neigh):
    return stats.mode(np.array(get_neigh(train, test_row, num_neigh))[:,-1]).mode

# %%
# !wget https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# Out:
# --2021-02-19 03:56:21--  https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# Resolving www.cs.toronto.edu (www.cs.toronto.edu)... 128.100.3.30
# Connecting to www.cs.toronto.edu (www.cs.toronto.edu)|128.100.3.30|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 170498071 (163M) [application/x-gzip]
# Saving to: ‘cifar-10-python.tar.gz.1’
#
# cifar-10-python.tar 100%[===================>] 162.60M  2.16MB/s    in 88s
#
# 2021-02-19 03:57:50 (1.86 MB/s) - ‘cifar-10-python.tar.gz.1’ saved [170498071/170498071]

# %%
# !tar -xf cifar-10-python.tar.gz

# %%
import pickle

# %%
def unpickle(file):
    with open(file, 'rb') as fo:
        dic = pickle.load(fo, encoding='bytes')
    return dic

# %%
import os

# %%
def load_dataset():
    X,y =None,[]
    for filename in sorted(os.listdir('/'.join([os.getcwd(),'cifar-10-batches-py']))):
        if filename[:10] == 'data_batch':
            print('loaded',filename)
            a = unpickle('/'.join([os.getcwd(),'cifar-10-batches-py',filename]))
            y.extend(a[b'labels'])
            if X is None:
                X = np.moveaxis(a[b'data'].reshape(-1,3,32,32),1,-1)
            else:
                X = np.append(X, np.moveaxis(a[b'data'].reshape(-1,3,32,32),1,-1), axis=0)
    return X, np.array(y)

# %%
X,y = load_dataset()
# Out:
# loaded data_batch_1
# loaded data_batch_2
# loaded data_batch_3
# loaded data_batch_4
# loaded data_batch_5

# %%
def preprocess(X):
    bgr2gray_weights = [0.1140, 0.5870, 0.2989]
    gray = np.dot(X,bgr2gray_weights)
    gray = (gray-gray.mean(axis=0))/ 255.
    vec = gray.reshape(-1,1024)
    return vec

# %%
X_train = preprocess(X)

# %%
data = np.append(X_train,y.reshape(-1,1),axis=-1)

# %%
train, valid = data[:10000], data[40000:40100]

# %%
from tqdm import tqdm

# %%
preds = [predict_classification(train, valid_row,5) for valid_row in tqdm(valid)]
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
#
#
#
#   1%|          | 1/100 [00:04<08:10,  4.96s/it]
#
#
#
#   2%|▏         | 2/100 [00:10<08:13,  5.04s/it]
#
#
#
#   3%|▎         | 3/100 [00:14<08:00,  4.96s/it]
#
#
#
#   4%|▍         | 4/100 [00:19<07:53,  4.93s/it]
#
#
#
#   5%|▌         | 5/100 [00:24<07:56,  5.01s/it]
#
#
#
#   6%|▌         | 6/100 [00:29<07:49,  4.99s/it]
#
#
#
#   7%|▋         | 7/100 [00:34<07:42,  4.97s/it]
#
#
#
#   8%|▊         | 8/100 [00:39<07:34,  4.94s/it]
#
#
#
#   9%|▉         | 9/100 [00:44<07:32,  4.98s/it]
#
#
#
#  10%|█         | 10/100 [00:49<07:25,  4.95s/it]
#
#
#
#  11%|█         | 11/100 [00:54<07:20,  4.95s/it]
#
#
#
#  12%|█▏        | 12/100 [00:59<07:12,  4.91s/it]
#
#
#
#  13%|█▎        | 13/100 [01:04<07:06,  4.90s/it]
#
#
#
#  14%|█▍        | 14/100 [01:09<07:01,  4.90s/it]
#
#
#
#  15%|█▌        | 15/100 [01:14<06:58,  4.92s/it]
#
#
#
#  16%|█▌        | 16/100 [01:19<06:52,  4.92s/it]
#
#
#
#  17%|█▋        | 17/100 [01:23<06:46,  4.90s/it]
#
#
#
#  18%|█▊        | 18/100 [01:28<06:41,  4.89s/it]
#
#
#
#  19%|█▉        | 19/100 [01:33<06:36,  4.89s/it]
#
#
#
#  20%|██        | 20/100 [01:38<06:32,  4.91s/it]
#
#
#
#  21%|██        | 21/100 [01:44<06:43,  5.11s/it]
#
#
#
#  22%|██▏       | 22/100 [01:49<06:52,  5.29s/it]
#
#
#
#  23%|██▎       | 23/100 [01:55<06:48,  5.31s/it]
#
#
#
#  24%|██▍       | 24/100 [02:00<06:37,  5.23s/it]
#
#
#
#  25%|██▌       | 25/100 [02:05<06:35,  5.27s/it]
#
#
#
#  26%|██▌       | 26/100 [02:10<06:27,  5.24s/it]
#
#
#
#  27%|██▋       | 27/100 [02:16<06:36,  5.43s/it]
#
#
#
#  28%|██▊       | 28/100 [02:22<06:30,  5.42s/it]
#
#
#
#  29%|██▉       | 29/100 [02:27<06:20,  5.36s/it]
#
#
#
#  30%|███       | 30/100 [02:32<06:09,  5.28s/it]
#
#
#
#  31%|███       | 31/100 [02:37<06:02,  5.25s/it]
#
#
#
#  32%|███▏      | 32/100 [02:42<05:52,  5.18s/it]
#
#
#
#  33%|███▎      | 33/100 [02:47<05:44,  5.14s/it]
#
#
#
#  34%|███▍      | 34/100 [02:52<05:38,  5.13s/it]
#
#
#
#  35%|███▌      | 35/100 [02:57<05:32,  5.12s/it]
#
#
#
#  36%|███▌      | 36/100 [03:03<05:30,  5.16s/it]
#
#
#
#  37%|███▋      | 37/100 [03:08<05:27,  5.20s/it]
#
#
#
#  38%|███▊      | 38/100 [03:13<05:22,  5.20s/it]
#
#
#
#  39%|███▉      | 39/100 [03:18<05:12,  5.13s/it]
#
#
#
#  40%|████      | 40/100 [03:23<05:06,  5.11s/it]
#
#
#
#  41%|████      | 41/100 [03:28<05:02,  5.12s/it]
#
#
#
#  42%|████▏     | 42/100 [03:33<04:55,  5.10s/it]
#
#
#
#  43%|████▎     | 43/100 [03:39<04:55,  5.18s/it]
#
#
#
#  44%|████▍     | 44/100 [03:44<04:48,  5.16s/it]
#
#
#
#  45%|████▌     | 45/100 [03:49<04:40,  5.09s/it]
#
#
#
#  46%|████▌     | 46/100 [03:54<04:32,  5.05s/it]
#
#
#
#  47%|████▋     | 47/100 [03:59<04:29,  5.08s/it]
#
#
#
#  48%|████▊     | 48/100 [04:04<04:23,  5.07s/it]
#
#
#
#  49%|████▉     | 49/100 [04:09<04:16,  5.03s/it]
#
#
#
#  50%|█████     | 50/100 [04:14<04:10,  5.01s/it]
#
#
#
#  51%|█████     | 51/100 [04:19<04:03,  4.98s/it]
#
#
#
#  52%|█████▏    | 52/100 [04:24<03:57,  4.95s/it]
#
#
#
#  53%|█████▎    | 53/100 [04:28<03:51,  4.92s/it]
#
#
#
#  54%|█████▍    | 54/100 [04:33<03:43,  4.86s/it]
#
#
#
#  55%|█████▌    | 55/100 [04:38<03:37,  4.84s/it]
#
#
#
#  56%|█████▌    | 56/100 [04:43<03:32,  4.84s/it]
#
#
#
#  57%|█████▋    | 57/100 [04:48<03:30,  4.89s/it]
#
#
#
#  58%|█████▊    | 58/100 [04:53<03:25,  4.89s/it]
#
#
#
#  59%|█████▉    | 59/100 [04:58<03:21,  4.91s/it]
#
#
#
#  60%|██████    | 60/100 [05:02<03:15,  4.88s/it]
#
#
#
#  61%|██████    | 61/100 [05:07<03:09,  4.86s/it]
#
#
#
#  62%|██████▏   | 62/100 [05:12<03:04,  4.86s/it]
#
#
#
#  63%|██████▎   | 63/100 [05:17<02:59,  4.86s/it]
#
#
#
#  64%|██████▍   | 64/100 [05:22<02:57,  4.93s/it]
#
#
#
#  65%|██████▌   | 65/100 [05:27<02:52,  4.93s/it]
#
#
#
#  66%|██████▌   | 66/100 [05:32<02:47,  4.92s/it]
#
#
#
#  67%|██████▋   | 67/100 [05:37<02:42,  4.92s/it]
#
#
#
#  68%|██████▊   | 68/100 [05:42<02:37,  4.91s/it]
#
#
#
#  69%|██████▉   | 69/100 [05:47<02:35,  5.03s/it]
#
#
#
#  70%|███████   | 70/100 [05:52<02:34,  5.14s/it]
#
#
#
#  71%|███████   | 71/100 [05:58<02:35,  5.35s/it]
#
#
#
#  72%|███████▏  | 72/100 [06:04<02:31,  5.41s/it]
#
#
#
#  73%|███████▎  | 73/100 [06:10<02:27,  5.48s/it]
#
#
#
#  74%|███████▍  | 74/100 [06:15<02:25,  5.59s/it]
#
#
#
#  75%|███████▌  | 75/100 [06:20<02:15,  5.40s/it]
#
#
#
#  76%|███████▌  | 76/100 [06:25<02:07,  5.31s/it]
#
#
#
#  77%|███████▋  | 77/100 [06:31<02:03,  5.35s/it]
#
#
#
#  78%|███████▊  | 78/100 [06:36<01:54,  5.22s/it]
#
#
#
#  79%|███████▉  | 79/100 [06:41<01:48,  5.15s/it]
#
#
#
#  80%|████████  | 80/100 [06:46<01:42,  5.14s/it]
#
#
#
#  81%|████████  | 81/100 [06:51<01:39,  5.25s/it]
#
#
#
#  82%|████████▏ | 82/100 [06:57<01:35,  5.32s/it]
#
#
#
#  83%|████████▎ | 83/100 [07:02<01:29,  5.28s/it]
#
#
#
#  84%|████████▍ | 84/100 [07:07<01:25,  5.32s/it]
#
#
#
#  85%|████████▌ | 85/100 [07:13<01:20,  5.35s/it]
#
#
#
#  86%|████████▌ | 86/100 [07:18<01:13,  5.24s/it]
#
#
#
#  87%|████████▋ | 87/100 [07:23<01:07,  5.17s/it]
#
#
#
#  88%|████████▊ | 88/100 [07:28<01:01,  5.14s/it]
#
#
#
#  89%|████████▉ | 89/100 [07:33<00:55,  5.07s/it]
#
#
#
#  90%|█████████ | 90/100 [07:38<00:50,  5.03s/it]
#
#
#
#  91%|█████████ | 91/100 [07:43<00:45,  5.02s/it]
#
#
#
#  92%|█████████▏| 92/100 [07:48<00:39,  4.98s/it]
#
#
#
#  93%|█████████▎| 93/100 [07:52<00:34,  4.90s/it]
#
#
#
#  94%|█████████▍| 94/100 [07:57<00:29,  4.94s/it]
#
#
#
#  95%|█████████▌| 95/100 [08:02<00:24,  4.97s/it]
#
#
#
#  96%|█████████▌| 96/100 [08:07<00:19,  4.96s/it]
#
#
#
#  97%|█████████▋| 97/100 [08:12<00:14,  4.95s/it]
#
#
#
#  98%|█████████▊| 98/100 [08:17<00:09,  4.93s/it]
#
#
#
#  99%|█████████▉| 99/100 [08:22<00:04,  4.93s/it]
#
#
#
# 100%|██████████| 100/100 [08:27<00:00,  5.07s/it]

# %%
print('Accuracy',100*np.mean(np.array(preds).reshape(-1,1)==valid[:,-1]),' %')
# Out:
# Accuracy 9.82  %

# %%
from matplotlib import pyplot as plt

# %%
best,bestK= 0,0
ks, accs= [],[]
for k in range(5,25):
    y_hat = np.array([predict_classification(train, valid_row,k) for valid_row in valid]).reshape(-1,1)
    acc = 100*np.mean(preds==valid[:,-1])
    print('Accuracy',acc,' % for',k,'neighbours')
    accs.append(acc)
    ks.append(k)
    if acc>best:
        best = acc
        bestK = k
plt.plot(accs,ks)
print('The best value for k can be seen from the hockey graph is:',bestK)
